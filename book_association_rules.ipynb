# %% [markdown]
# # import libraries

# %%
import pandas as pd

from mlxtend.frequent_patterns import apriori,association_rules
from mlxtend.preprocessing import TransactionEncoder
import matplotlib.pyplot as plt
import seaborn as sns

import warnings 
warnings.filterwarnings("ignore")

# %%
pip install mlxtend
# Out:
# ...
# Note: you may need to restart the kernel to use updated packages.

# %%
pd.set_option("display.max_rows",500)
pd.set_option("display.max_columns",500)

# %%
ls
# Out:
#  Volume in drive C is Acer
#  Volume Serial Number is 361B-9495
#
#  Directory of C:\Users\Karthik\Downloads\assignments\association rules
#
# 25-01-2023  12:11    <DIR>          .
# 23-01-2023  11:08    <DIR>          ..
# 25-01-2023  11:44    <DIR>          .ipynb_checkpoints
# 06-01-2023  20:13            46,094 book.csv
# 25-01-2023  12:11            19,886 book_association_rules.ipynb
# 06-01-2023  20:13               767 my_movies.csv
# 06-01-2023  20:13               274 Problem_Statment.txt
#                4 File(s)         67,021 bytes
#                3 Dir(s)  335,030,394,880 bytes free

# %%
book=pd.read_csv("book.csv")
book.sample(10)
# Out:
#       ChildBks  YouthBks  CookBks  DoItYBks  RefBks  ArtBks  GeogBks  \
# 271          1         1        1         1       1       0        0
# 1645         0         0        1         0       0       0        0
# 1644         1         0        1         0       0       0        0
# 1002         1         0        1         1       1       1        1
# 1037         0         0        0         0       0       0        0
# 372          0         0        1         0       0       0        1
# 83           1         1        1         1       1       0        0
# 538          0         0        0         0       0       0        0
# 9            1         1        1         0       0       0        1
# 1500         0         0        1         0       0       0        0
#
#       ItalCook  ItalAtlas  ItalArt  Florence
# 271          0          0        0         0
# 1645         0          0        0         0
# 1644         0          0        0         0
# ...

# %%
book.shape
# Out:
# (2000, 11)

# %%
for i in book.columns:
    print(i)
    print(book[i].value_counts())
# Out:
# ChildBks
# 0    1154
# 1     846
# Name: ChildBks, dtype: int64
# YouthBks
# 0    1505
# 1     495
# Name: YouthBks, dtype: int64
# CookBks
# 0    1138
# 1     862
# Name: CookBks, dtype: int64
# DoItYBks
# 0    1436
# 1     564
# Name: DoItYBks, dtype: int64
# RefBks
# 0    1571
# 1     429
# Name: RefBks, dtype: int64
# ArtBks
# 0    1518
# 1     482
# Name: ArtBks, dtype: int64
# GeogBks
# 0    1448
# 1     552
# Name: GeogBks, dtype: int64
# ItalCook
# 0    1773
# 1     227
# Name: ItalCook, dtype: int64
# ItalAtlas
# 0    1926
# 1      74
# Name: ItalAtlas, dtype: int64
# ItalArt
# 0    1903
# 1      97
# Name: ItalArt, dtype: int64
# Florence
# 0    1783
# 1     217
# Name: Florence, dtype: int64

# %%
book.columns
# Out:
# Index(['ChildBks', 'YouthBks', 'CookBks', 'DoItYBks', 'RefBks', 'ArtBks',
#        'GeogBks', 'ItalCook', 'ItalAtlas', 'ItalArt', 'Florence'],
#       dtype='object')

# %%
l1=['ChildBks', 'YouthBks', 'CookBks', 'DoItYBks', 'RefBks', 'ArtBks',
       'GeogBks', 'ItalCook', 'ItalAtlas', 'ItalArt', 'Florence']
fig=plt.figure(figsize=(20,13))
for i in range (len(l1)):
    column=l1[i]
    sub=fig.add_subplot(4,3,i+1)
    chart=sns.countplot(data=book,x=column)

# %%
book.tail()
# Out:
#       ChildBks  YouthBks  CookBks  DoItYBks  RefBks  ArtBks  GeogBks  \
# 1995         0         0        1         0       0       1        1
# 1996         0         0        0         0       0       0        0
# 1997         0         0        0         0       0       0        0
# 1998         0         0        1         0       0       0        0
# 1999         0         0        0         0       0       0        0
#
#       ItalCook  ItalAtlas  ItalArt  Florence
# 1995         1          0        1         1
# 1996         0          0        0         0
# 1997         0          0        0         0
# 1998         0          0        0         0
# 1999         0          0        0         0

# %% [markdown]
# # Apriori Algorithm

# %%
frequent_itemsets=apriori(book,min_support=0.12,use_colnames=True)
frequent_itemsets
# Out:
#     support                       itemsets
# 0    0.4230                     (ChildBks)
# 1    0.2475                     (YouthBks)
# 2    0.4310                      (CookBks)
# 3    0.2820                     (DoItYBks)
# 4    0.2145                       (RefBks)
# 5    0.2410                       (ArtBks)
# 6    0.2760                      (GeogBks)
# 7    0.1650           (YouthBks, ChildBks)
# 8    0.2560            (CookBks, ChildBks)
# 9    0.1840           (ChildBks, DoItYBks)
# 10   0.1515             (RefBks, ChildBks)
# 11   0.1625             (ArtBks, ChildBks)
# 12   0.1950            (GeogBks, ChildBks)
# 13   0.1620            (CookBks, YouthBks)
# 14   0.1205            (GeogBks, YouthBks)
# 15   0.1875            (CookBks, DoItYBks)
# 16   0.1525              (RefBks, CookBks)
# 17   0.1670              (CookBks, ArtBks)
# 18   0.1925             (GeogBks, CookBks)
# 19   0.1235             (ArtBks, DoItYBks)
# 20   0.1325            (GeogBks, DoItYBks)
# ...

# %%
book[book["CookBks"]==1].shape[0]/book.shape[0]
# Out:
# 0.431

# %%
rules=association_rules(frequent_itemsets,metric="lift",min_threshold=0.6)

# %%
rules
# Out:
#              antecedents           consequents  antecedent support  \
# 0               (RefBks)            (ChildBks)              0.2145
# 1             (ChildBks)              (RefBks)              0.4230
# 2              (GeogBks)            (ChildBks)              0.2760
# 3             (ChildBks)             (GeogBks)              0.4230
# 4              (GeogBks)            (YouthBks)              0.2760
# 5             (YouthBks)             (GeogBks)              0.2475
# 6               (RefBks)             (CookBks)              0.2145
# 7              (CookBks)              (RefBks)              0.4310
# 8              (CookBks)              (ArtBks)              0.4310
# 9               (ArtBks)             (CookBks)              0.2410
# 10             (GeogBks)             (CookBks)              0.2760
# 11             (CookBks)             (GeogBks)              0.4310
# 12              (ArtBks)            (DoItYBks)              0.2410
# ...

# %%
rules=association_rules(frequent_itemsets,metric="lift",min_threshold=0.9)

# %%
rules
# Out:
#              antecedents           consequents  antecedent support  \
# 0             (YouthBks)            (ChildBks)              0.2475
# 1             (ChildBks)            (YouthBks)              0.4230
# 2              (CookBks)            (ChildBks)              0.4310
# 3             (ChildBks)             (CookBks)              0.4230
# 4             (ChildBks)            (DoItYBks)              0.4230
# 5             (DoItYBks)            (ChildBks)              0.2820
# 6               (RefBks)            (ChildBks)              0.2145
# 7             (ChildBks)              (RefBks)              0.4230
# 8               (ArtBks)            (ChildBks)              0.2410
# 9             (ChildBks)              (ArtBks)              0.4230
# 10             (GeogBks)            (ChildBks)              0.2760
# 11            (ChildBks)             (GeogBks)              0.4230
# 12             (CookBks)            (YouthBks)              0.4310
# ...

# %%
rules=association_rules(frequent_itemsets,metric="support",min_threshold=0.15)

# %%
rules
# Out:
#    antecedents consequents  antecedent support  consequent support  support  \
# 0   (YouthBks)  (ChildBks)              0.2475              0.4230   0.1650
# 1   (ChildBks)  (YouthBks)              0.4230              0.2475   0.1650
# 2    (CookBks)  (ChildBks)              0.4310              0.4230   0.2560
# 3   (ChildBks)   (CookBks)              0.4230              0.4310   0.2560
# 4   (ChildBks)  (DoItYBks)              0.4230              0.2820   0.1840
# 5   (DoItYBks)  (ChildBks)              0.2820              0.4230   0.1840
# 6     (RefBks)  (ChildBks)              0.2145              0.4230   0.1515
# 7   (ChildBks)    (RefBks)              0.4230              0.2145   0.1515
# 8     (ArtBks)  (ChildBks)              0.2410              0.4230   0.1625
# 9   (ChildBks)    (ArtBks)              0.4230              0.2410   0.1625
# 10   (GeogBks)  (ChildBks)              0.2760              0.4230   0.1950
# ...

# %%
rules=association_rules(frequent_itemsets,metric="support",min_threshold=0.18)

# %%
rules
# Out:
#   antecedents consequents  antecedent support  consequent support  support  \
# 0   (CookBks)  (ChildBks)               0.431               0.423   0.2560
# 1  (ChildBks)   (CookBks)               0.423               0.431   0.2560
# 2  (ChildBks)  (DoItYBks)               0.423               0.282   0.1840
# 3  (DoItYBks)  (ChildBks)               0.282               0.423   0.1840
# 4   (GeogBks)  (ChildBks)               0.276               0.423   0.1950
# 5  (ChildBks)   (GeogBks)               0.423               0.276   0.1950
# 6   (CookBks)  (DoItYBks)               0.431               0.282   0.1875
# 7  (DoItYBks)   (CookBks)               0.282               0.431   0.1875
# 8   (GeogBks)   (CookBks)               0.276               0.431   0.1925
# 9   (CookBks)   (GeogBks)               0.431               0.276   0.1925
#
#    confidence      lift  leverage  conviction
# 0    0.593968  1.404179  0.073687    1.421069
# 1    0.605201  1.404179  0.073687    1.441240
# ...

# %%
rules=association_rules(frequent_itemsets,metric="confidence",min_threshold=0.20)

# %%
rules
# Out:
#              antecedents           consequents  antecedent support  \
# 0             (YouthBks)            (ChildBks)              0.2475
# 1             (ChildBks)            (YouthBks)              0.4230
# 2              (CookBks)            (ChildBks)              0.4310
# 3             (ChildBks)             (CookBks)              0.4230
# 4             (ChildBks)            (DoItYBks)              0.4230
# 5             (DoItYBks)            (ChildBks)              0.2820
# 6               (RefBks)            (ChildBks)              0.2145
# 7             (ChildBks)              (RefBks)              0.4230
# 8               (ArtBks)            (ChildBks)              0.2410
# 9             (ChildBks)              (ArtBks)              0.4230
# 10             (GeogBks)            (ChildBks)              0.2760
# 11            (ChildBks)             (GeogBks)              0.4230
# 12             (CookBks)            (YouthBks)              0.4310
# ...

# %%
rules=association_rules(frequent_itemsets,metric="confidence",min_threshold=0.22)

# %%
rules
# Out:
#              antecedents           consequents  antecedent support  \
# 0             (YouthBks)            (ChildBks)              0.2475
# 1             (ChildBks)            (YouthBks)              0.4230
# 2              (CookBks)            (ChildBks)              0.4310
# 3             (ChildBks)             (CookBks)              0.4230
# 4             (ChildBks)            (DoItYBks)              0.4230
# 5             (DoItYBks)            (ChildBks)              0.2820
# 6               (RefBks)            (ChildBks)              0.2145
# 7             (ChildBks)              (RefBks)              0.4230
# 8               (ArtBks)            (ChildBks)              0.2410
# 9             (ChildBks)              (ArtBks)              0.4230
# 10             (GeogBks)            (ChildBks)              0.2760
# 11            (ChildBks)             (GeogBks)              0.4230
# 12             (CookBks)            (YouthBks)              0.4310
# ...
